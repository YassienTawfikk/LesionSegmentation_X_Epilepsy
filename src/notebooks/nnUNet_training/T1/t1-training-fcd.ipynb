# %% [markdown]
# ## INSTALL NNUNetv2 AND DEPENDENCIES

# %%
# !pip install nnunetv2 --quiet
# !pip install nibabel simpleitk --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/211.5 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 kB 8.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/363.4 MB ? eta -:--:--
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/363.4 MB 90.0 MB/s eta 0:00:04
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/363.4 MB 187.3 MB/s eta 0:00:02
# ...

# %% [markdown]
# ## IMPORTS AND ENVIRONMENT SETUP

# %%
import os

# Your dataset name
DATASET_ID = "001"
DATASET_NAME = f"Dataset{DATASET_ID}_BonnFCD"

# Set up environment variables for nnUNetv2
os.environ["nnUNet_raw"] = "/kaggle/input/preprocessed-dataset-t1/nnUNet_raw_data"
os.environ["nnUNet_preprocessed"] = "/kaggle/input/preprocessed-dataset-t1/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/kaggle/working/nnUNet_results"

# Check setup
# !echo "Raw Data Path: $nnUNet_raw"
# !echo "Preprocessed Path: $nnUNet_preprocessed"
# !echo "Results Path: $nnUNet_results"
# !ls $nnUNet_preprocessed
# Out:
# Raw Data Path: /kaggle/input/preprocessed-dataset-t1/nnUNet_raw_data
# Preprocessed Path: /kaggle/input/preprocessed-dataset-t1/nnUNet_preprocessed
# Results Path: /kaggle/working/nnUNet_results
# Dataset001_BonnFCD

# %%
# 🔧 Disable torch.compile for compatibility with older GPUs (like Tesla P100)
import os
os.environ["NNUNET_USE_TORCH_COMPILE"] = "0"   # <- main fix
os.environ["TORCH_COMPILE_DISABLE"] = "1"       # <- extra safety
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torch._dynamo
torch._dynamo.config.suppress_errors = True

print("Torch Compile disabled. Ready to train nnU-Net safely on Tesla P100 ✅")
# Out:
# Torch Compile disabled. Ready to train nnU-Net safely on Tesla P100 ✅

# %% [markdown]
# ## VERIFY DATASET INTEGRITY

# %%
# Copy dataset to a writable directory
# !cp -r /kaggle/input/preprocessed-dataset-t1 /kaggle/working/

# Verify structure
# !ls /kaggle/working/preprocessed-dataset-t1/nnUNet_raw_data
# !ls /kaggle/working/preprocessed-dataset-t1/nnUNet_preprocessed

# Set nnUNet environment variables to point to the working directory
import os
os.environ["nnUNet_raw"] = "/kaggle/working/preprocessed-dataset-t1/nnUNet_raw_data"
os.environ["nnUNet_preprocessed"] = "/kaggle/working/preprocessed-dataset-t1/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/kaggle/working/nnUNet_results"

# Run preprocessing check again
# !nnUNetv2_plan_and_preprocess -d 1 --verify_dataset_integrity
# Out:
# Dataset001_BonnFCD
# Dataset001_BonnFCD
# Fingerprint extraction...
# Dataset001_BonnFCD
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> reader/writer
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
# Experiment planning...
#
# ############################
# INFO: You are using the old nnU-Net default planner. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
# Attempting to find 3d_lowres config.
# Current spacing: [1.03 1.03 1.03].
# Current patch size: (160, 160, 96).
# Current median shape: [247.57281553 247.57281553 155.33980583]
# Dropping 3d_lowres config because the image size difference to 3d_fullres is too small. 3d_fullres: [255. 255. 160.], 3d_lowres: [248, 248, 155]
# 2D U-Net configuration:
# ...

# %% [markdown]
# ## TRAINING (3D Full Resolution)

# %%
import os
os.environ["NNUNET_USE_TORCH_COMPILE"] = "0"

import torch._dynamo
torch._dynamo.config.suppress_errors = True

# %%
# !nnUNetv2_train 1 3d_fullres 0 --c
# !nnUNetv2_train 1 3d_fullres 1 --c
# !nnUNetv2_train 1 3d_fullres 2 --c
# !nnUNetv2_train 1 3d_fullres 3 --c
# !nnUNetv2_train 1 3d_fullres 4 --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# WARNING: Cannot continue training because there seems to be no checkpoint available to continue from. Starting a new training...
# 2025-10-15 22:35:05.727231: Using torch.compile...
# 2025-10-15 22:35:07.652993: do_dummy_2d_data_aug: False
# ...
